# %% [markdown]
# ## Name : Adwaiy Singh
# ## Reg. No. : 220968424
# ## Sec. : A
# ## Batch: 2
#
# # WEEK 1
# ## Q 5 to 6 (DataSet 1)

# %% [markdown]
# ### Question 5

# %% [markdown]
# ## a. Import the required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## b. Load the dataset.

# %%
data1=pd.read_csv("Data1.csv")
df=data1
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## c. Examine data information

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## d. Identify and analyze null values using df. isnull()

# %%
data1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## e. Conduct statistical analysis. (count, mean, SD, min, max, Quartile)

# %%
data1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## f. Generate boxplots for each column to detect outliers

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=data1)
plt.title('Boxplot')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ## g. Determine quartiles and remove outliers

# %%
for col in data1.columns:
    q1=data1[col].quantile(0.25)
    q3=data1[col].quantile(0.75)
    iqr=q3-q1
    low=q1-(1.5*iqr)
    high=q3+(1.5*iqr)
    data1 = data1.loc[(data1[col] > low) & (data1[col] < high)]
    
print(data1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## h. Calculate correlations and visualize them with a heatmap.

# %%
sns.heatmap(data1.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## i. Normalize the various features of the given datasets. (MinMaxScaler)

# %%
normal=MinMaxScaler()
normalized=normal.fit_transform(data1)
data1=pd.DataFrame(normalized, columns= data1.columns)

# %%
data1
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.461538  0.675325       0.500000       0.583333  0.000000  0.488889
# 1       0.076923  0.266234       0.411765       0.483333  0.000000  0.266667
# 2       0.615385  0.902597       0.382353       0.000000  0.000000  0.161905
# 3       0.076923  0.292208       0.411765       0.383333  0.286585  0.314286
# 4       0.384615  0.467532       0.529412       0.000000  0.000000  0.234921
# ..           ...       ...            ...            ...       ...       ...
# 631     0.769231  0.370130       0.558824       0.800000  0.548780  0.466667
# 632     0.153846  0.506494       0.470588       0.450000  0.000000  0.590476
# 633     0.384615  0.500000       0.500000       0.383333  0.341463  0.253968
# 634     0.076923  0.532468       0.323529       0.000000  0.000000  0.377778
# 635     0.076923  0.318182       0.470588       0.516667  0.000000  0.387302
#
# ...

# %% [markdown]
# ## j. Arrange correlation values for each attribute in ascending order.

# %%
corr_mat = data1.corr(method='pearson') 
sorted_mat = corr_mat.unstack().sort_values()

# %%
sorted_mat
# Out:
# SkinThickness  Age             -0.121766
# Age            SkinThickness   -0.121766
# Pregnancies    SkinThickness   -0.090282
# SkinThickness  Pregnancies     -0.090282
# Insulin        Pregnancies     -0.089290
#                                   ...
# SkinThickness  SkinThickness    1.000000
# BloodPressure  BloodPressure    1.000000
# Glucose        Glucose          1.000000
# Age            Age              1.000000
# Outcome        Outcome          1.000000
# Length: 81, dtype: float64

# %% [markdown]
# # Question 6

# %% [markdown]
# ## a. Scatter plots with coloured points and adjustable sizes using columns
# ## (1) col1, col2

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['Pregnancies'],data1['Glucose'],color='purple')
plt.xlabel('Pregnancies')
plt.ylabel('Glucose')
plt.show()

# %% [markdown]
# ## (2) col3, col4

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['BloodPressure'],data1['SkinThickness'],color='blue')
plt.xlabel('BloodPressure')
plt.ylabel('SkinThickness')
plt.show()

# %% [markdown]
# ## (3) col5, col6.

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['BMI'],data1['Insulin'],color='red')
plt.xlabel('BMI')
plt.ylabel('Insulin')
plt.show()

# %% [markdown]
# ## b. Line charts for columns
# ## (1) col1, col2

# %%
sns.lineplot(data = data1, x=data1['Pregnancies'],y=data1['Glucose'],color='purple')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %% [markdown]
# ## (2) col3, col4

# %%
sns.lineplot(data= data1, x=data1['BloodPressure'],y=data1['SkinThickness'],color='blue')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='SkinThickness'>

# %% [markdown]
# ## (3) col5, col6

# %%
sns.lineplot(data= data1, x=data1['BMI'],y=data1['Insulin'],color='red')
# Out:
# <Axes: xlabel='BMI', ylabel='Insulin'>

# %% [markdown]
# ## c. Bar charts representing columns
# ## (1) col1, col2

# %%
sns.barplot(x='Pregnancies', y='Glucose',data=data1)
plt.show()

# %% [markdown]
# ## (2) col3, col4

# %%
sns.barplot(x='BloodPressure', y='SkinThickness',data=data1)
plt.show()

# %% [markdown]
# ## (3) col5, col6.

# %%
sns.barplot(x='BMI', y='Insulin',data=data1)
plt.show()

# %% [markdown]
# ## d. Histograms to depict the dataset's distribution.

# %%
for col in data1.columns:
    sns.displot(data = data1, x=col, bins=20)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %% [markdown]
# ## e. Employ Bokeh for interactive data visualization.

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.io import output_notebook


col1 = 'Pregnancies'
col2 = 'Glucose'

output_notebook()

p = figure(title=f'Interactive Scatter Plot of {col1} vs {col2}', 
           x_axis_label=col1, y_axis_label=col2,
           tools='pan,box_zoom,reset,hover,save')

scatter = p.circle(x=df[col1], y=df[col2], size=8, color='red', alpha=0.7)

hover = HoverTool()
hover.tooltips = [(f'{col1}', f'@{col1}'), (f'{col2}', f'@{col2}')]
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d0767c03-6949-45f9-bba0-3e010d766320">Loading BokehJS ...</span>
#     </div>
#   <div id="f1fe6243-77ad-4368-917a-431684779534" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ## f.Utilize Bokeh's GUI features, including buttons, sliders, checkboxes, and radio buttons.

# %%
from bokeh.io import curdoc
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, Button, Slider, CheckboxGroup, RadioGroup
from bokeh.layouts import column, row


source = ColumnDataSource(data1)

p = figure(title="Interactive Scatter Plot", x_axis_label='BLOCKS', y_axis_label='VILLAGES')
scatter = p.circle(x='Pregnancies', y='Glucose', source=source, size=8, color='blue', alpha=0.7)

hover = HoverTool()
hover.tooltips = [("Pregnancies", "@Pregnancies"), ("Glucose", "@Glucose")]
p.add_tools(hover)

button = Button(label="Randomize Data", button_type="success")
slider = Slider(title="Size", value=8, start=1, end=20, step=1)
checkbox_group = CheckboxGroup(labels=["Show Scatter Plot"], active=[0])
radio_group = RadioGroup(labels=["Blue", "Red"], active=0)

def update_plot():
    scatter.glyph.size = slider.value

button.on_click(update_plot)
slider.on_change('value', lambda attr, old, new: update_plot())

layout = column(
    row(button, slider),
    row(checkbox_group, radio_group),
    p
)

curdoc().add_root(layout)
show(layout, notebook_handle=True)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
#   <div id="af4c4033-9ee0-434b-a867-fa5c97e813a6" data-root-id="p1209" style="display: contents;"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[34]</strong>&gt;</code></p>

# %% [markdown]
# ## g. Employ Plotly to create a dropdown menu.

# %%
import plotly.graph_objects as px 

np.random.seed(42) 
  
random_x = np.random.randint(1, 101, 100) 
random_y = np.random.randint(1, 101, 100) 
  
plot = px.Figure(data=[px.Scatter( 
    x=data1['Pregnancies'], 
    y=data1['Glucose'], 
    mode='markers',) 
]) 
  
plot.update_layout( 
    updatemenus=[ 
        dict( 
            buttons=list([ 
                dict( 
                    args=["type", "scatter"], 
                    label="Scatter Plot", 
                    method="restyle"
                ), 
                dict( 
                    args=["type", "bar"], 
                    label="Bar Chart", 
                    method="restyle"
                ) 
            ]), 
            direction="down", 
        ), 
    ] 
) 
  
plot.show()
# Out:
# <div>                            <div id="835dcd8b-a62f-41a0-aecc-56514b1fefcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("835dcd8b-a62f-41a0-aecc-56514b1fefcd")) {                    Plotly.newPlot(                        "835dcd8b-a62f-41a0-aecc-56514b1fefcd",                        [{"mode":"markers","x":[0.46153846153846156,0.07692307692307693,0.6153846153846154,0.07692307692307693,0.38461538461538464,0.23076923076923078,0.3076923076923077,0.7692307692307693,0.38461538461538464,0.0,0.5384615384615385,0.07692307692307693,0.23076923076923078,0.6153846153846154,0.5384615384615385,0.6923076923076923,0.8461538461538463,0.7692307692307693,0.5384615384615385,0.07692307692307693,1.0,0.38461538461538464,0.38461538461538464,0.23076923076923078,0.2307
# ...

# %% [markdown]
# ## h. Develop custom action buttons using Plotly.

# %%
import plotly.graph_objects as px 
import numpy 

x = data1['BMI']

plot = px.Figure(data=[px.Bar( 
    name='Pregnancies', 
    x=x, 
    y=data1['Pregnancies'] 
), 
    px.Bar( 
    name='Glucose', 
    x=x, 
    y=data1['Glucose'] 
) 
]) 


plot.update_layout( 
    updatemenus=[ 
        dict( 
            type="buttons", 
            direction="left", 
            buttons=list([ 
                dict(label="Both", 
                    method="update", 
                    args=[{"visible": [True, True]}, 
                        {"title": "Both"}]), 
                dict(label="Pregnancies", 
                    method="update", 
                    args=[{"visible": [True, False]}, 
                          {"title": "Data 1", 
                          }]), 
                dict(label="Glucose", 
                     method="update", 
                     args=[{"visible": [False, True]}, 
                           {"title": "Data 2", 
                           }]), 
            ]), 
        ) 
    ]) 

plot.show()
# Out:
# <div>                            <div id="99b8785f-4cc4-4641-a3f8-6edb9ad775df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99b8785f-4cc4-4641-a3f8-6edb9ad775df")) {                    Plotly.newPlot(                        "99b8785f-4cc4-4641-a3f8-6edb9ad775df",                        [{"name":"Pregnancies","x":[0.48888888888888893,0.2666666666666667,0.161904761904762,0.3142857142857144,0.23492063492063497,0.40634920634920635,0.6158730158730159,0.6285714285714286,0.2412698412698413,0.876190476190476,0.36190476190476195,0.5206349206349208,0.6698412698412697,0.5460317460317459,0.6857142857142855,0.34285714285714286,0.5841269841269843,0.4095238095238096,0.6730158730158728,0.15873015873015872,0.12698412698412698,0.5047619047619047,0.565079365079365
# ...
